# %%
import pandas as pd
import os

# %%
csv_files = ['./alk_with_descriptors.csv','./braf_with_descriptors.csv']

# %%
combined_df = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)
# Out:
# C:\Users\Anay\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:1: DtypeWarning: Columns (0,1,7,8,13,14,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# C:\Users\Anay\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:1: DtypeWarning: Columns (0,1,7,8,13,14,16,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.

# %%
combined_df
# Out:
#                                              action_type activity_comment  \
# 0                                                    NaN              NaN
# 1                                                    NaN              NaN
# 2                                                    NaN              NaN
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 10477  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 10478  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 10479  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 10480  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 10481  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
#
#        activity_id                                activity_properties  \
# ...

# %%
combined_df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0         NaN              NaN      1675255                  []
# 1         NaN              NaN      1675268                  []
# 2         NaN              NaN      1675270                  []
# 3         NaN              NaN      1675272                  []
# 4         NaN              NaN      1675274                  []
#
#   assay_chembl_id                assay_description assay_type  \
# 0    CHEMBL867052  Inhibitory activity against ALK          B
# 1    CHEMBL867052  Inhibitory activity against ALK          B
# 2    CHEMBL867052  Inhibitory activity against ALK          B
# 3    CHEMBL867052  Inhibitory activity against ALK          B
# 4    CHEMBL867052  Inhibitory activity against ALK          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...        YN  \
# 0                     NaN                    NaN  BAO_0000190  ...  0.000618
# ...

# %%
combined_df.to_csv('new_combined_proteins.csv', index=False)
